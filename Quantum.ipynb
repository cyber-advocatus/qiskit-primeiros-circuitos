# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit import QuantumCircuit

service = QiskitRuntimeService()
print("Conectado com sucesso!")

qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

qc.draw('mpl')
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-05-09 23:56:34,817: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# Conectado com sucesso!
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[1], line 11
#       8 qc.h(0)
#       9 qc.measure(0, 0)
# ---> 11 qc.draw('mpl')
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:4040, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#    3895 r"""Draw the quantum circuit. Use the output parameter to choose the drawing format:
#    3896
#    3897 ``text``
#    (...)   4035        qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#    4036 """
#    4038 from qiskit.visualization import circuit_drawer
# -> 4040 return circuit_drawer(
#    4041     self,
#    4042     scale=scale,
#    4043     filename=filename,
#    4044     style=style,
#    4045     output=output,
#    4046     interactive=interactive,
#    4047     plot_barriers=plot_barriers,
#    4048     reverse_bits=reverse_bits,
#    4049     justify=justify,
#    4050     vertical_compression=vertical_compression,
#    4051     idle_wires=idle_wires,
#    4052     with_layout=with_layout,
#    4053     fold=fold,
#    4054     ax=ax,
#    4055     initial_state=initial_state,
#    4056     cregbundle=cregbundle,
#    4057     wire_order=wire_order,
#    4058     expr_len=expr_len,
#    4059     barrier_label_len=barrier_label_len,
#    4060     measure_arrows=measure_arrows,
#    4061 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/visualization/circuit/circuit_visualization.py:368, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     352     return _generate_latex_source(
#     353         circuit,
#     354         filename=filename,
#    (...)    365         barrier_label_len=barrier_label_len,
#     366     )
#     367 elif output == "mpl":
# --> 368     image = _matplotlib_circuit_drawer(
#     369         circuit,
#     370         scale=scale,
#     371         filename=filename,
#     372         style=style,
#     373         plot_barriers=plot_barriers,
#     374         reverse_bits=reverse_bits,
#     375         justify=justify,
#     376         idle_wires=idle_wires,
#     377         with_layout=with_layout,
#     378         fold=fold,
#     379         ax=ax,
#     380         initial_state=initial_state,
#     381         cregbundle=cregbundle,
#     382         wire_order=complete_wire_order,
#     383         expr_len=expr_len,
#     384         measure_arrows=measure_arrows,
#     385         barrier_label_len=barrier_label_len,
#     386     )
#     387 else:
#     388     raise VisualizationError(
#     389         f"Invalid output type {output} selected. The only valid choices "
#     390         "are text, latex, latex_source, and mpl"
#     391     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/visualization/circuit/circuit_visualization.py:776, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     773 if fold is None:
#     774     fold = 25
# --> 776 qcd = _matplotlib.MatplotlibDrawer(
#     777     qubits,
#     778     clbits,
#     779     nodes,
#     780     circuit,
#     781     scale=scale,
#     782     style=style,
#     783     reverse_bits=reverse_bits,
#     784     plot_barriers=plot_barriers,
#     785     fold=fold,
#     786     ax=ax,
#     787     initial_state=initial_state,
#     788     cregbundle=cregbundle,
#     789     with_layout=with_layout,
#     790     expr_len=expr_len,
#     791     barrier_label_len=barrier_label_len,
#     792     measure_arrows=measure_arrows,
#     793 )
#     794 return qcd.draw(filename)
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/utils/classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/utils/lazy_tester.py:42, in _RequireNow.__call__(self, *_args, **_kwargs)
#      41 def __call__(self, *_args, **_kwargs):
# ---> 42     self._tester.require_now(self._feature)
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/utils/lazy_tester.py:222, in LazyDependencyManager.require_now(self, feature)
#     220 if self:
#     221     return
# --> 222 raise MissingOptionalLibraryError(
#     223     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     224 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %%
# !pip install matplotlib
# Out:
# zsh:1: command not found: pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install qiskit-ibm-runtime qiskit matplotlib
# Out:
# Collecting qiskit-ibm-runtime
#   Using cached qiskit_ibm_runtime-0.46.1-py3-none-any.whl.metadata (21 kB)
# Collecting qiskit
#   Using cached qiskit-2.4.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: requests>=2.32.4 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.32.5)
# Collecting requests-ntlm>=1.1.0 (from qiskit-ibm-runtime)
#   Using cached requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.3.5)
# Requirement already satisfied: urllib3>=2.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.55.3 (from qiskit-ibm-runtime)
#   Using cached ibm_platform_services-0.75.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting ibm-quantum-schemas>=0.5.20260320 (from qiskit-ibm-runtime)
#   Using cached ibm_quantum_schemas-0.7.20260419-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit-ibm-runtime) (2.12.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from qiskit-ibm-runtime) (25.0)
# Collecting pybase64>=1.4 (from qiskit-ibm-runtime)
#   Using cached pybase64-1.4.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting samplomatic>=0.13.0 (from qiskit-ibm-runtime)
#   Using cached samplomatic-0.18.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: scipy>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /opt/anaconda3/lib/python3.13/site-packages (from qiskit) (0.4.0)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Using cached stevedore-5.7.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.13/site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime)
#   Using cached ibm_cloud_sdk_core-3.24.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting PyJWT<3.0.0,>=2.11.0 (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime)
#   Using cached pyjwt-2.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.9.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2026.4.22)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: cryptography>=1.3 in /opt/anaconda3/lib/python3.13/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.3)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit-ibm-runtime)
#   Using cached pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.23)
# Collecting orjson>=3.9.0 (from samplomatic>=0.13.0->qiskit-ibm-runtime)
#   Using cached orjson-3.11.9-cp313-cp313-macosx_15_0_arm64.whl.metadata (41 kB)
# Using cached qiskit_ibm_runtime-0.46.1-py3-none-any.whl (1.5 MB)
# Using cached qiskit-2.4.1-cp310-abi3-macosx_11_0_arm64.whl (8.3 MB)
# Using cached ibm_platform_services-0.75.0-py3-none-any.whl (386 kB)
# Using cached ibm_cloud_sdk_core-3.24.4-py3-none-any.whl (75 kB)
# Using cached pyjwt-2.12.1-py3-none-any.whl (29 kB)
# Using cached ibm_quantum_schemas-0.7.20260419-py3-none-any.whl (102 kB)
# Using cached pybase64-1.4.3-cp313-cp313-macosx_11_0_arm64.whl (31 kB)
# Using cached requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Using cached pyspnego-0.12.1-py3-none-any.whl (130 kB)
# Using cached rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl (2.0 MB)
# Using cached samplomatic-0.18.0-py3-none-any.whl (212 kB)
# Using cached orjson-3.11.9-cp313-cp313-macosx_15_0_arm64.whl (128 kB)
# Using cached stevedore-5.7.0-py3-none-any.whl (54 kB)
# Installing collected packages: stevedore, rustworkx, PyJWT, pybase64, orjson, qiskit, ibm_cloud_sdk_core, samplomatic, pyspnego, ibm-platform-services, requests-ntlm, ibm-quantum-schemas, qiskit-ibm-runtime
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.10.1
#     Uninstalling PyJWT-2.10.1:
#       Successfully uninstalled PyJWT-2.10.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [qiskit-ibm-runtime]m 12/13 [qiskit-ibm-runtime]es]
# Successfully installed PyJWT-2.12.1 ibm-platform-services-0.75.0 ibm-quantum-schemas-0.7.20260419 ibm_cloud_sdk_core-3.24.4 orjson-3.11.9 pybase64-1.4.3 pyspnego-0.12.1 qiskit-2.4.1 qiskit-ibm-runtime-0.46.1 requests-ntlm-1.3.0 rustworkx-0.17.1 samplomatic-0.18.0 stevedore-5.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit import QuantumCircuit

service = QiskitRuntimeService()
print("Conectado com sucesso!")

qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

qc.draw('mpl')
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-05-09 23:57:13,380: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# Conectado com sucesso!
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[2], line 11
#       8 qc.h(0)
#       9 qc.measure(0, 0)
# ---> 11 qc.draw('mpl')
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:4040, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#    3895 r"""Draw the quantum circuit. Use the output parameter to choose the drawing format:
#    3896
#    3897 ``text``
#    (...)   4035        qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#    4036 """
#    4038 from qiskit.visualization import circuit_drawer
# -> 4040 return circuit_drawer(
#    4041     self,
#    4042     scale=scale,
#    4043     filename=filename,
#    4044     style=style,
#    4045     output=output,
#    4046     interactive=interactive,
#    4047     plot_barriers=plot_barriers,
#    4048     reverse_bits=reverse_bits,
#    4049     justify=justify,
#    4050     vertical_compression=vertical_compression,
#    4051     idle_wires=idle_wires,
#    4052     with_layout=with_layout,
#    4053     fold=fold,
#    4054     ax=ax,
#    4055     initial_state=initial_state,
#    4056     cregbundle=cregbundle,
#    4057     wire_order=wire_order,
#    4058     expr_len=expr_len,
#    4059     barrier_label_len=barrier_label_len,
#    4060     measure_arrows=measure_arrows,
#    4061 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/visualization/circuit/circuit_visualization.py:368, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     352     return _generate_latex_source(
#     353         circuit,
#     354         filename=filename,
#    (...)    365         barrier_label_len=barrier_label_len,
#     366     )
#     367 elif output == "mpl":
# --> 368     image = _matplotlib_circuit_drawer(
#     369         circuit,
#     370         scale=scale,
#     371         filename=filename,
#     372         style=style,
#     373         plot_barriers=plot_barriers,
#     374         reverse_bits=reverse_bits,
#     375         justify=justify,
#     376         idle_wires=idle_wires,
#     377         with_layout=with_layout,
#     378         fold=fold,
#     379         ax=ax,
#     380         initial_state=initial_state,
#     381         cregbundle=cregbundle,
#     382         wire_order=complete_wire_order,
#     383         expr_len=expr_len,
#     384         measure_arrows=measure_arrows,
#     385         barrier_label_len=barrier_label_len,
#     386     )
#     387 else:
#     388     raise VisualizationError(
#     389         f"Invalid output type {output} selected. The only valid choices "
#     390         "are text, latex, latex_source, and mpl"
#     391     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/visualization/circuit/circuit_visualization.py:776, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     773 if fold is None:
#     774     fold = 25
# --> 776 qcd = _matplotlib.MatplotlibDrawer(
#     777     qubits,
#     778     clbits,
#     779     nodes,
#     780     circuit,
#     781     scale=scale,
#     782     style=style,
#     783     reverse_bits=reverse_bits,
#     784     plot_barriers=plot_barriers,
#     785     fold=fold,
#     786     ax=ax,
#     787     initial_state=initial_state,
#     788     cregbundle=cregbundle,
#     789     with_layout=with_layout,
#     790     expr_len=expr_len,
#     791     barrier_label_len=barrier_label_len,
#     792     measure_arrows=measure_arrows,
#     793 )
#     794 return qcd.draw(filename)
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/utils/classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/utils/lazy_tester.py:42, in _RequireNow.__call__(self, *_args, **_kwargs)
#      41 def __call__(self, *_args, **_kwargs):
# ---> 42     self._tester.require_now(self._feature)
#
# File /opt/anaconda3/lib/python3.13/site-packages/qiskit/utils/lazy_tester.py:222, in LazyDependencyManager.require_now(self, feature)
#     220 if self:
#     221     return
# --> 222 raise MissingOptionalLibraryError(
#     223     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     224 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %%
pip install pylatexenc
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (pyproject.toml) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136897 sha256=164df73ce4d117d71f453d2416f31ff7874e235bdbe8575aa5de4c8df58d4d13
#   Stored in directory: /Users/091sd3/Library/Caches/pip/wheels/3c/d9/c1/bb2a15d13c742b9035ef7ae6ebe236af270b1d1d9b386dcd5e
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit import QuantumCircuit

service = QiskitRuntimeService()
print("Conectado com sucesso!")

qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

qc.draw('mpl')
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-05-09 23:59:15,954: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# Conectado com sucesso!
