# %%
sampler = StatevectorSampler()
job = sampler.run([qc], shots=1000)
result = job.result()

counts = result[0].data.c.get_counts()
print("Resultados:", counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sampler = StatevectorSampler()
#       2 job = sampler.run([qc], shots=1000)
#       3 result = job.result()
#
# NameError: name 'StatevectorSampler' is not defined

# %%
from qiskit.primitives import StatevectorSampler

sampler = StatevectorSampler()
job = sampler.run([qc], shots=1000)
result = job.result()

counts = result[0].data.c.get_counts()
print("Resultados:", counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from qiskit.primitives import StatevectorSampler
#       3 sampler = StatevectorSampler()
# ----> 4 job = sampler.run([qc], shots=1000)
#       5 result = job.result()
#       7 counts = result[0].data.c.get_counts()
#
# NameError: name 'qc' is not defined

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

sampler = StatevectorSampler()
job = sampler.run([qc], shots=1000)
result = job.result()

counts = result[0].data.c.get_counts()
print("Resultados:", counts)
# Out:
# Resultados: {'11': 511, '00': 489}

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

sampler = StatevectorSampler()
job = sampler.run([qc], shots=1000)
result = job.result()

counts = result[0].data.c.get_counts()
print("Resultados:", counts)
# Out:
# Resultados: {'00': 515, '11': 485}
